# %%
#! /usr/bin/env python
#  -*- coding: utf-8 -*-
#
# GUI module generated by PAGE version 5.4
#  in conjunction with Tcl version 8.6
#    Apr 10, 2021 03:26:15 PM IST  platform: Windows NT

import sys

try:
    import Tkinter as tk
except ImportError:
    import tkinter as tk

try:
    import ttk
    py3 = False
except ImportError:
    import tkinter.ttk as ttk
    py3 = True

import SAP_support

def vp_start_gui():
    '''Starting point when module is the main routine.'''
    global val, w, root
    root = tk.Tk()
    top = Toplevel1 (root)
    SAP_support.init(root, top)
    root.mainloop()

w = None
def create_Toplevel1(rt, *args, **kwargs):
    '''Starting point when module is imported by another module.
       Correct form of call: 'create_Toplevel1(root, *args, **kwargs)' .'''
    global w, w_win, root
    #rt = root
    root = rt
    w = tk.Toplevel (root)
    top = Toplevel1 (w)
    SAP_support.init(w, top, *args, **kwargs)
    return (w, top)

def destroy_Toplevel1():
    global w
    w.destroy()
    w = None

class Toplevel1:
    
    def null(self):
        import numpy as np
        import pandas as pd
        from PIL import ImageTk, Image

        ex = pd.read_csv("EQ_2021_Data_Sample.csv")
        nu = ex.isnull().sum()
        nbsrt = nu.sort_values(ascending=False)

        bar = nbsrt.plot(kind="bar",figsize=(20,15))
        fig = bar.get_figure()
        fig.savefig(r"barnull.jpg")
        gif1 = tk.PhotoImage(file=r'barnull.jpg')
        self.Canvas1.create_image(0, 0, image=gif1,anchor=tk.NW)
        #img = ImageTk.PhotoImage(Image.open(r"health.jpg"))
        #self.Canvas1.create_image(0, 0, anchor=tk.NW, image=img)
        #self.Label1.configure(image=img)
        
        
        self.Text1.configure(state=tk.NORMAL)
        self.Text1.delete("0.0",tk.END)
        self.Text1.insert(tk.END,"Done"+'\n\n')
        self.Text1.configure(foreground="#442265",font=("Verdana",12))
    
    
    
    
    def __init__(self, top=None):
        '''This class configures and populates the toplevel window.
           top is the toplevel containing window.'''
        _bgcolor = '#d9d9d9'  # X11 color: 'gray85'
        _fgcolor = '#000000'  # X11 color: 'black'
        _compcolor = '#d9d9d9' # X11 color: 'gray85'
        _ana1color = '#d9d9d9' # X11 color: 'gray85'
        _ana2color = '#ececec' # Closest X11 color: 'gray92'

        top.geometry("600x681+885+162")
        top.minsize(148, 1)
        top.maxsize(1906, 1037)
        top.resizable(1, 1)
        top.title("New Toplevel")
        top.configure(background="#d9d9d9")
        top.configure(highlightbackground="#d9d9d9")
        top.configure(highlightcolor="black")

        self.Button1 = tk.Button(top)
        self.Button1.place(relx=0.433, rely=0.734, height=43, width=66)
        self.Button1.configure(activebackground="#ececec")
        self.Button1.configure(activeforeground="#000000")
        self.Button1.configure(background="#d9d9d9")
        self.Button1.configure(disabledforeground="#a3a3a3")
        self.Button1.configure(foreground="#000000")
        self.Button1.configure(highlightbackground="#d9d9d9")
        self.Button1.configure(highlightcolor="black")
        self.Button1.configure(pady="0")
        self.Button1.configure(text='''Null''', command = self.null)

        self.Text1 = tk.Text(top)
        self.Text1.place(relx=0.15, rely=0.602, relheight=0.079, relwidth=0.423)
        self.Text1.configure(background="white")
        self.Text1.configure(font="TkTextFont")
        self.Text1.configure(foreground="black")
        self.Text1.configure(highlightbackground="#d9d9d9")
        self.Text1.configure(highlightcolor="black")
        self.Text1.configure(insertbackground="black")
        self.Text1.configure(selectbackground="blue")
        self.Text1.configure(selectforeground="white")
        self.Text1.configure(wrap="word")

        self.Canvas1 = tk.Canvas(top)
        self.Canvas1.place(relx=0.217, rely=0.103, relheight=0.401
                , relwidth=0.588)
        self.Canvas1.configure(background="#d9d9d9")
        self.Canvas1.configure(borderwidth="2")
        self.Canvas1.configure(insertbackground="black")
        self.Canvas1.configure(relief="ridge")
        self.Canvas1.configure(selectbackground="#ffffff")
        self.Canvas1.configure(selectforeground="white")

        self.Label1 = tk.Label(top)
        self.Label1.place(relx=0.683, rely=0.69, height=66, width=102)
        self.Label1.configure(background="#d9d9d9")
        self.Label1.configure(disabledforeground="#a3a3a3")
        self.Label1.configure(foreground="#000000")
        self.Label1.configure(text='''Label''')

if __name__ == '__main__':
    vp_start_gui()
# Out:
# <ipython-input-13-4d61f96edae1>:30: DtypeWarning: Columns (31,32,33,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   root.mainloop()

# %%
import numpy as np
import pandas as pd

ex = pd.read_csv("EQ_2021_Data_Sample.csv")
nu = ex.isnull().sum()
nbsrt = nu.sort_values(ascending=False)

bar = nbsrt.plot(kind="bar",figsize=(20,15))
fig = bar.get_figure()
fig.savefig("photo/barnull.jpeg")
# Out:
# c:\users\admin\desktop\realbiz\mlchatbot\venv\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (31,32,33,34) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
class Toplevel1:
    def null(self):
        import numpy as np
        import pandas as pd
        from PIL import ImageTk, Image

        ex = pd.read_csv("EQ_2021_Data_Sample.csv")
        nu = ex.isnull().sum()
        nbsrt = nu.sort_values(ascending=False)

        bar = nbsrt.plot(kind="bar",figsize=(20,15))
        fig = bar.get_figure()
        fig.savefig(r"barnull.png")
        #gif1 = tk.PhotoImage(file=r'barnull.png')
        #self.Canvas1.create_image(10, 10, image=gif1,anchor=tk.CENTER)
        img = ImageTk.PhotoImage(Image.open(r"barnull.png"))
        #self.Canvas1.create_image(20, 20, anchor=tk.NW, image=img)
        #self.Label1.configure(image=img)
        
        
        self.Text1.configure(state=tk.NORMAL)
        self.Text1.delete("0.0",tk.END)
        self.Text1.insert(tk.END,"Done"+'\n\n')
        self.Text1.configure(foreground="#442265",font=("Verdana",12))
